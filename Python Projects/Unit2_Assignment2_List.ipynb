# %% [markdown]
# <a href="https://colab.research.google.com/github/niteen11/lagcc_data_analytics_micro_credential/blob/master/Unit%202%20-%20Python%20Fundamentals/Assignments/Unit2_List_Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Intrdouction to Python - List - Assingment #2

# %% [markdown]
# ## 1.Create a list of 5 of your favorite tv shows.  ?

# %%
my_fave = ["Halt and Catch Fire", "StartUp", "Game of Thrones", "Vikings", "The Walking Dead"]

# %% [markdown]
# ## 2.	Print the list in its original order

# %%
print(my_fave)
# Out:
# ['Halt and Catch Fire', 'StartUp', 'Game of Thrones', 'Vikings', 'The Walking Dead']

# %% [markdown]
# ## 3.	Use the sorted() function to print the list in alphabetical order.  How is sorted() different from sort()?

# %%
print(sorted(my_fave))
# Out:
# ['Game of Thrones', 'Halt and Catch Fire', 'StartUp', 'The Walking Dead', 'Vikings']

# %% [markdown]
# The sorted() function will keep the original list (temporary) while the sort() method will overwrite the original (permanent).

# %% [markdown]
# ## 4.	Print out your original list.

# %%
print(my_fave)
# Out:
# ['Halt and Catch Fire', 'StartUp', 'Game of Thrones', 'Vikings', 'The Walking Dead']

# %% [markdown]
# ## 5.	Used sorted() to print your list in reverse alphabetical order.

# %%
print(sorted(my_fave, reverse=True))
# Out:
# ['Vikings', 'The Walking Dead', 'StartUp', 'Halt and Catch Fire', 'Game of Thrones']

# %% [markdown]
# ## 6.	Create a message indicating how many favorite TV shows you have – use the len() function.

# %%
# Get the length, convert to str, and store in variable the total number of tv shows.
number_of_shows = str(len(my_fave))

# %%
print("I have a total number of " + number_of_shows + " TV shows.")
# Out:
# I have a total number of 5 TV shows.
